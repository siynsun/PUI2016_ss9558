# %%
import os
import numpy as np
from numpy.random import randn
import pylab as pl

from pandas import Series, DataFrame
import pandas
import pandas as pd
data = os.getenv("DFDATA")
print (data)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
# setting up some preferences
# %pylab inline

np.set_printoptions(precision=4, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#hw2_3data=pd.read_csv(data + "/uedp-fegm.csv")
hw2_3data=pd.read_csv("https://data.cityofnewyork.us/resource/uedp-fegm.csv")
hw2_3data.head()
# Out:
#                                          Zip Code  \
# 0  10001\n(40.75025902143676, -73.99688630375988)
# 1  10002\n(40.71612146793143, -73.98583147024613)
# 2  10003\n(40.73194394755518, -73.98887214913032)
# 3   10005\n(40.7061257920717, -74.00858468583453)
# 4  10006\n(40.70825614030866, -74.01355356964149)
#
#   Building type (service class   Consumption (therms)    Consumption (GJ)   \
# 0                  Residential                 58338.0              6155.0
# 1                  Residential                550055.0             58034.0
# 2                  Residential                260502.0             27484.0
# 3                  Residential                   265.0                28.0
# 4                  Residential                  2076.0               219.0
#
#   Utility/Data Source
# 0               ConEd
# 1               ConEd
# 2               ConEd
# 3               ConEd
# 4               ConEd

# %%
hw2_3data.drop(['Zip Code','Building type (service class','Utility/Data Source'], axis=1, inplace=True)
hw2_3data
# Out:
#       Consumption (therms)    Consumption (GJ)
# 0                   58338.0              6155.0
# 1                  550055.0             58034.0
# 2                  260502.0             27484.0
# 3                     265.0                28.0
# 4                    2076.0               219.0
# 5                   12845.0              1355.0
# 6                  186224.0             19648.0
# 7                   61263.0              6464.0
# 8                  192654.0             20326.0
# 9                  178497.0             18832.0
# 10                 228453.0             24103.0
# 11                 213234.0             22497.0
# 12                 111236.0             11736.0
# 13                  23970.0              2529.0
# 14                  21822.0              2302.0
# 15                 124706.0             13157.0
# 16                 185761.0             19599.0
# 17                 122395.0             12913.0
# 18                 243744.0             25716.0
# ...

# %%
df=hw2_3data
df.columns = ['therms_consumption','GJ_consumption']
# Out:
#      therms_consumption  GJ_consumption
# 0               58338.0          6155.0
# 1              550055.0         58034.0
# 2              260502.0         27484.0
# 3                 265.0            28.0
# 4                2076.0           219.0
# 5               12845.0          1355.0
# 6              186224.0         19648.0
# 7               61263.0          6464.0
# 8              192654.0         20326.0
# 9              178497.0         18832.0
# 10             228453.0         24103.0
# 11             213234.0         22497.0
# 12             111236.0         11736.0
# 13              23970.0          2529.0
# 14              21822.0          2302.0
# 15             124706.0         13157.0
# 16             185761.0         19599.0
# 17             122395.0         12913.0
# 18             243744.0         25716.0
# 19             403600.0         42582.0
# 20             507504.0         53545.0
# 21             148829.0         15702.0
# ...

# %%
plot=df.plot.scatter(x='therms_consumption',y='GJ_consumption',label='consumption')
plot.set_title("Scatter plot of therms consumption and GJ consumption")
plot.set_ylabel('GJ comsumption')
plt.show()
